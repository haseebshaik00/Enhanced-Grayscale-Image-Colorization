# %% [markdown]
# <a href="https://colab.research.google.com/github/haseebshaik00/Enhanced-Grayscale-Image-Colorization/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Enhanced Grayscale Images Colorization </h1>

# %% [markdown]
# <h2>Library imports</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from keras.layers import Dense, Input, Conv2D, Flatten, Reshape, Conv2DTranspose, Dropout
from keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.datasets import cifar10
from keras import backend as K
import pandas as pd

# %% [markdown]
# <h2>Defining the RGB to Gray Transition function

# %%
#Using cv2.cvtcolor(image, cv2.color_scheme)
#Input coloured image and returned the gray image
def rgb_gray(img):
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray_img

# %% [markdown]
# <h2>Loading Data</h2>

# %%
#Loading the training and testing dataset from Keras datasets
#Here, x_train is our training set and x_test is our validation set
#We do not require the y_train/y_test dataset as we are not performing image classification with target labels
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#Dimensions of each of the sets
print(x_train.shape)
print(x_test.shape)
#Getting the height, width and number of channels from the image
img_dim = x_train.shape[1]
channels = 3
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# <h2>Displaying sample images from the dataset with their respective class</h2>

# %%
#Display sample images from the dataset
fig, ax = plt.subplots(5,5,sharex=True,sharey=True,figsize=(10,10))
c=0
for i in range(0,5):
    for j in range (0,5):
        ax[i,j].imshow(x_train[c])
        ax[i,j].set_title(y_train[c])
        c=c+1
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# <h2>Conversion process and storing them in a list</h2>

# %%
im1 = x_train[0]
fig, ax = plt.subplots(ncols = 2)
ax[0].imshow(im1)
im2 = cv2.cvtColor(im1, cv2.COLOR_RGB2GRAY)
ax[1].imshow(im2, cmap='gray')

# %%
#Our lists to store the converted images
x_train_Gray = []
x_test_Gray = []
#Iterate over number of images for training set
for i in range(x_train.shape[0]):
 img = x_train[i]
 #convert and append
 x_train_Gray.append(rgb_gray(img))
print(len(x_train_Gray))
# Out:
# 50000

# %%
#Same process for the test images
for i in range(x_test.shape[0]):
 img = x_test[i]
 x_test_Gray.append(rgb_gray(img))
print(len(x_test_Gray))
# Out:
# 10000

# %% [markdown]
# <h2>Image Pre-processing</h2>

# %%
#Convert the given list to a numpy array for input
x_train_Gray = np.asarray(x_train_Gray)
x_test_Gray = np.asarray(x_test_Gray)

#Reshape the given data into (m - no. of samples, height, width, channels)
#We will reshape both the training coloured and gray images - Features and targets
x_train = x_train.reshape(x_train.shape[0], img_dim, img_dim, channels)
x_test = x_test.reshape(x_test.shape[0], img_dim, img_dim, channels)
x_train_Gray = x_train_Gray.reshape(x_train_Gray.shape[0], img_dim,
img_dim, 1)
x_test_Gray = x_test_Gray.reshape(x_test_Gray.shape[0], img_dim,img_dim,1)
input_shape = (img_dim, img_dim, 1)
lat_dim = 256

# %% [markdown]
# <h2>Normalizing pixels over the range [0-1]

# %%
#Dividing each pixel by 255 to get a normalized value
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
x_train_Gray = x_train_Gray.astype('float32')/255
x_test_Gray = x_test_Gray.astype('float32')/255

# %% [markdown]
# <h2>Example of sample image and converted image (after passing through black and white function)</h2>

# %% [markdown]
# 50000, 32, 32, 3

# %% [markdown]
# <h2>Initialization of the encoder model</h2>

# %%
#ENCODER MODEL
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
x = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x)
x = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x)
shape = K.int_shape(x)
x = Flatten()(x)
latent = Dense(256, name='latent_vector')(x)
encoder = Model(inputs, latent, name='encoder_model')
encoder.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 256)         295168
#
#  flatten (Flatten)           (None, 4096)              0
#
#  latent_vector (Dense)       (None, 256)               1048832
#
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Initialization of the decoder model</h2>

# %%
#DECODER MODEL
latent_inputs = Input(shape = (lat_dim,), name = 'decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)
x = Conv2DTranspose(256, (3,3), strides = 2, activation = 'relu', padding= 'same')(x)
x = Conv2DTranspose(128, (3,3), strides = 2, activation = 'relu', padding= 'same')(x)
x = Conv2DTranspose(64, (3,3), strides = 2, activation = 'relu', padding ='same')(x)
outputs = Conv2DTranspose(3, (3,3), activation = 'sigmoid', padding = 'same', name = 'decoder_output')(x)
decoder = Model(latent_inputs, outputs, name = 'decoder_model')
decoder.summary()
# Out:
# Model: "decoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 256)]             0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  reshape (Reshape)           (None, 4, 4, 256)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 256)        590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  decoder_output (Conv2DTrans  (None, 32, 32, 3)        1731
#  pose)
#
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Auto-encoder model</h2>

# %%
#AUTOENCODER MODEL
autoencoder = Model(inputs, decoder(encoder(inputs)), name = 'autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  encoder_model (Functional)  (None, 256)               1418496
#
#  decoder_model (Functional)  (None, 32, 32, 3)         2013315
#
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Learning rate scheduling and checkpoint callbacks</h2>

# %%
#Learning Rate plateau and scheduling
lr_reducer = ReduceLROnPlateau(factor = np.sqrt(0.1), cooldown = 0, patience = 5, verbose = 1, min_lr = 0.5e-6)
#Preparing save location during model training
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.h5'

#Creating dir to save the model
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)

#Checkpoint and learning rate scheduling callback
checkpoints = ModelCheckpoint(filepath = filepath, monitor = 'val_loss', verbose = 1, save_best_only = True)
callbacks = [lr_reducer]
# Out:
# /content/saved_models/colorized_ae_model.h5

# %% [markdown]
# <h2>Training the model over the given dataset over batches and epochs</h2>

# %%
#TRAINING
#Using the desired loss function, optimizer and metric
autoencoder.compile(loss = "mse", optimizer = 'Adam', metrics = ['accuracy'])
#Fit the model with the training set and validation set
history = autoencoder.fit(x_train_Gray, x_train, validation_data = (x_test_Gray, x_test),epochs = 50, batch_size = 32, callbacks = callbacks)
x_decoded = autoencoder.predict(x_test_Gray)
autoencoder.save('colourization_model.h5')
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 29s 11ms/step - loss: 0.0151 - accuracy: 0.4886 - val_loss: 0.0107 - val_accuracy: 0.4946 - lr: 0.0010
# Epoch 2/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0099 - accuracy: 0.5064 - val_loss: 0.0092 - val_accuracy: 0.5126 - lr: 0.0010
# Epoch 3/50
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.0089 - accuracy: 0.5135 - val_loss: 0.0086 - val_accuracy: 0.5257 - lr: 0.0010
# Epoch 4/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0084 - accuracy: 0.5191 - val_loss: 0.0082 - val_accuracy: 0.5226 - lr: 0.0010
# Epoch 5/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0080 - accuracy: 0.5245 - val_loss: 0.0080 - val_accuracy: 0.4967 - lr: 0.0010
# Epoch 6/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0077 - accuracy: 0.5273 - val_loss: 0.0077 - val_accuracy: 0.5168 - lr: 0.0010
# Epoch 7/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0075 - accuracy: 0.5318 - val_loss: 0.0077 - val_accuracy: 0.5188 - lr: 0.0010
# Epoch 8/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0073 - accuracy: 0.5375 - val_loss: 0.0076 - val_accuracy: 0.5173 - lr: 0.0010
# Epoch 9/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0071 - accuracy: 0.5414 - val_loss: 0.0076 - val_accuracy: 0.5181 - lr: 0.0010
# Epoch 10/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0069 - accuracy: 0.5466 - val_loss: 0.0076 - val_accuracy: 0.4931 - lr: 0.0010
# Epoch 11/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0067 - accuracy: 0.5507 - val_loss: 0.0078 - val_accuracy: 0.5133 - lr: 0.0010
# Epoch 12/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0065 - accuracy: 0.5561 - val_loss: 0.0079 - val_accuracy: 0.5266 - lr: 0.0010
# Epoch 13/50
# 1559/1563 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.5608
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0062 - accuracy: 0.5607 - val_loss: 0.0080 - val_accuracy: 0.4981 - lr: 0.0010
# Epoch 14/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0054 - accuracy: 0.5799 - val_loss: 0.0073 - val_accuracy: 0.5259 - lr: 3.1623e-04
# Epoch 15/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0052 - accuracy: 0.5856 - val_loss: 0.0073 - val_accuracy: 0.5275 - lr: 3.1623e-04
# Epoch 16/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0050 - accuracy: 0.5901 - val_loss: 0.0074 - val_accuracy: 0.5165 - lr: 3.1623e-04
# Epoch 17/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0049 - accuracy: 0.5940 - val_loss: 0.0074 - val_accuracy: 0.5270 - lr: 3.1623e-04
# Epoch 18/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0048 - accuracy: 0.5978 - val_loss: 0.0075 - val_accuracy: 0.5147 - lr: 3.1623e-04
# Epoch 19/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.6014
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0046 - accuracy: 0.6014 - val_loss: 0.0074 - val_accuracy: 0.5155 - lr: 3.1623e-04
# Epoch 20/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0043 - accuracy: 0.6118 - val_loss: 0.0075 - val_accuracy: 0.5144 - lr: 1.0000e-04
# Epoch 21/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0043 - accuracy: 0.6141 - val_loss: 0.0075 - val_accuracy: 0.5157 - lr: 1.0000e-04
# Epoch 22/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0042 - accuracy: 0.6156 - val_loss: 0.0076 - val_accuracy: 0.5211 - lr: 1.0000e-04
# Epoch 23/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0042 - accuracy: 0.6177 - val_loss: 0.0076 - val_accuracy: 0.5138 - lr: 1.0000e-04
# Epoch 24/50
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.6196
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0041 - accuracy: 0.6196 - val_loss: 0.0076 - val_accuracy: 0.5138 - lr: 1.0000e-04
# Epoch 25/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0040 - accuracy: 0.6235 - val_loss: 0.0076 - val_accuracy: 0.5089 - lr: 3.1623e-05
# Epoch 26/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0040 - accuracy: 0.6245 - val_loss: 0.0076 - val_accuracy: 0.5132 - lr: 3.1623e-05
# Epoch 27/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0040 - accuracy: 0.6250 - val_loss: 0.0076 - val_accuracy: 0.5139 - lr: 3.1623e-05
# Epoch 28/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0040 - accuracy: 0.6256 - val_loss: 0.0076 - val_accuracy: 0.5072 - lr: 3.1623e-05
# Epoch 29/50
# 1558/1563 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.6262
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0040 - accuracy: 0.6262 - val_loss: 0.0076 - val_accuracy: 0.5105 - lr: 3.1623e-05
# Epoch 30/50
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.0039 - accuracy: 0.6276 - val_loss: 0.0076 - val_accuracy: 0.5105 - lr: 1.0000e-05
# Epoch 31/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6279 - val_loss: 0.0076 - val_accuracy: 0.5129 - lr: 1.0000e-05
# Epoch 32/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6283 - val_loss: 0.0077 - val_accuracy: 0.5076 - lr: 1.0000e-05
# Epoch 33/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6284 - val_loss: 0.0077 - val_accuracy: 0.5085 - lr: 1.0000e-05
# Epoch 34/50
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.6287
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6287 - val_loss: 0.0077 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 35/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6289 - val_loss: 0.0077 - val_accuracy: 0.5079 - lr: 3.1623e-06
# Epoch 36/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6290 - val_loss: 0.0077 - val_accuracy: 0.5094 - lr: 3.1623e-06
# Epoch 37/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6293 - val_loss: 0.0077 - val_accuracy: 0.5094 - lr: 3.1623e-06
# Epoch 38/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6293 - val_loss: 0.0077 - val_accuracy: 0.5095 - lr: 3.1623e-06
# Epoch 39/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.6293
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000553323957e-06.
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6293 - val_loss: 0.0077 - val_accuracy: 0.5088 - lr: 3.1623e-06
# Epoch 40/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6295 - val_loss: 0.0077 - val_accuracy: 0.5095 - lr: 1.0000e-06
# Epoch 41/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6295 - val_loss: 0.0077 - val_accuracy: 0.5095 - lr: 1.0000e-06
# Epoch 42/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6296 - val_loss: 0.0077 - val_accuracy: 0.5098 - lr: 1.0000e-06
# Epoch 43/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6296 - val_loss: 0.0077 - val_accuracy: 0.5094 - lr: 1.0000e-06
# Epoch 44/50
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.6296
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5e-07.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6296 - val_loss: 0.0077 - val_accuracy: 0.5096 - lr: 1.0000e-06
# Epoch 45/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6297 - val_loss: 0.0077 - val_accuracy: 0.5097 - lr: 5.0000e-07
# Epoch 46/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6295 - val_loss: 0.0077 - val_accuracy: 0.5099 - lr: 5.0000e-07
# Epoch 47/50
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.0039 - accuracy: 0.6296 - val_loss: 0.0077 - val_accuracy: 0.5100 - lr: 5.0000e-07
# Epoch 48/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0039 - accuracy: 0.6298 - val_loss: 0.0077 - val_accuracy: 0.5095 - lr: 5.0000e-07
# Epoch 49/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0039 - accuracy: 0.6298 - val_loss: 0.0077 - val_accuracy: 0.5090 - lr: 5.0000e-07
# Epoch 50/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0039 - accuracy: 0.6294 - val_loss: 0.0077 - val_accuracy: 0.5098 - lr: 5.0000e-07
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# <h2>Loading the model and checking out the results</h2>

# %%
from google.colab import files
#files.download('colourization_model.h5')
#Displaying Results
imgs = x_test[:25]
imgs = imgs.reshape((5, 5, img_dim, img_dim, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Original Image')
plt.imshow(imgs, interpolation='none')
#plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()
imgs = x_decoded[:25]
imgs = imgs.reshape((5, 5, img_dim, img_dim, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
#plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()

# %%
plt.imshow(x_decoded[2])

# %%
plt.imshow(x_test[2])

# %%
df = pd.DataFrame(history.history)
df[['accuracy','val_accuracy']].plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.xlabel("epochs")
plt.title('Train and Validation Accuracy')
plt.show()

# %%
df[['val_loss']].plot()
plt.xlabel("epochs")
plt.title('Validation Loss')
plt.show()
#MSE on validation data x_test_gray, x_test

# %%
df[['loss']].plot()
plt.xlabel("epochs")
plt.title('Training Loss')
plt.show()
#MSE on training data x_train_gray, x_train
